# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !wget https://nlp.stanford.edu/data/gqa/images.zip
# !mv images.zip ./drive/MyDrive/datasets
# Out:
# --2023-02-23 06:21:44--  https://nlp.stanford.edu/data/gqa/images.zip
# Resolving nlp.stanford.edu (nlp.stanford.edu)... 171.64.67.140
# Connecting to nlp.stanford.edu (nlp.stanford.edu)|171.64.67.140|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://downloads.cs.stanford.edu/nlp/data/gqa/images.zip [following]
# --2023-02-23 06:21:44--  https://downloads.cs.stanford.edu/nlp/data/gqa/images.zip
# Resolving downloads.cs.stanford.edu (downloads.cs.stanford.edu)... 171.64.64.22
# Connecting to downloads.cs.stanford.edu (downloads.cs.stanford.edu)|171.64.64.22|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 21817965542 (20G) [application/zip]
# Saving to: ‘images.zip’
#
# images.zip          100%[===================>]  20.32G  5.04MB/s    in 69m 16s
#
# 2023-02-23 07:31:00 (5.01 MB/s) - ‘images.zip’ saved [21817965542/21817965542]

# %%
# !wget http://images.cocodataset.org/zips/train2014.zip
# !mv train2014.zip ./drive/MyDrive/datasets
# Out:
# --2023-02-23 14:08:24--  http://images.cocodataset.org/zips/train2014.zip
# Resolving images.cocodataset.org (images.cocodataset.org)... 52.216.88.67, 52.217.96.60, 54.231.199.17, ...
# Connecting to images.cocodataset.org (images.cocodataset.org)|52.216.88.67|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 13510573713 (13G) [application/zip]
# Saving to: ‘train2014.zip’
#
# train2014.zip       100%[===================>]  12.58G  15.3MB/s    in 14m 54s
#
# 2023-02-23 14:23:18 (14.4 MB/s) - ‘train2014.zip’ saved [13510573713/13510573713]

# %%
# !wget https://zenodo.org/record/4729015/files/mdetr_annotations.tar.gz
# !mv mdetr_annotations.tar.gz ./drive/MyDrive/datasets
# Out:
# --2023-02-23 16:52:29--  https://zenodo.org/record/4729015/files/mdetr_annotations.tar.gz
# Resolving zenodo.org (zenodo.org)... 188.185.124.72
# Connecting to zenodo.org (zenodo.org)|188.185.124.72|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1080389728 (1.0G) [application/octet-stream]
# Saving to: ‘mdetr_annotations.tar.gz’
#
# mdetr_annotations.t 100%[===================>]   1.01G   643KB/s    in 24m 51s
#
# 2023-02-23 17:17:22 (707 KB/s) - ‘mdetr_annotations.tar.gz’ saved [1080389728/1080389728]

# %%
# !wget https://github.com/BryanPlummer/flickr30k_entities/raw/master/annotations.zip
# !mv annotations.zip ./drive/MyDrive/datasets
# Out:
# --2023-02-23 17:51:28--  https://github.com/BryanPlummer/flickr30k_entities/raw/master/annotations.zip
# Resolving github.com (github.com)... 140.82.114.3
# Connecting to github.com (github.com)|140.82.114.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/BryanPlummer/flickr30k_entities/master/annotations.zip [following]
# --2023-02-23 17:51:28--  https://raw.githubusercontent.com/BryanPlummer/flickr30k_entities/master/annotations.zip
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.108.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 29284070 (28M) [application/zip]
# Saving to: ‘annotations.zip’
#
# annotations.zip     100%[===================>]  27.93M  --.-KB/s    in 0.1s
#
# ...

# %%
# Get download link from http://shannon.cs.illinois.edu/DenotationGraph/data/index.html
# !wget -O flickr30k-images.tar.gz https://dl2.boxcloud.com/d/1/b1!gCn8lFBS78f-PSrPRqGBBuNEh3ScTcDSHI9b7c0lMuybQQeoAcZ7FdFzbsYVLsE35WSKeK-DgjUeRylLsSBTsBTzEOdWU_na92FFIJ83LjokHEh1DTtdC6CAWa94gElyaG5M8S1uO2kS3zWvaLNh8eKoxQ8jjmpoyD9QbQfpANV17k-y95e6301fqE80juOF_BCJ1-vGBPvrjiW2xqIg5pd4jNrbm3wASwmBYVVxIGcwiajgSK5NW87xpTBrwb62HRbU68rc_mQ3Gv7_U_-Sa9TMWWbSrqeM0dLtDtrxleDGgpUhXrbvYArUx28NBZbfUxHTw_HLmg1xpwDQZVJG6KWobW2JKidL-sOVlvEaCPvjeQuBsga9j1G-eJjVZpRo-t8jJb8WJ02sbLWeDe9FptvNhg3yCxJCfbze_Sk7SQjSfewsr-LklVL13ge8oND4VGI2M8DEzA1io9i4lZWp9e4OUhVvk7lO5v5vyLGwQAqKz
CmT4O4BOZcZ29HS2ecK35-qq7WmQsulbqGLwixJNnrm22ObeNdqUXpa-iaK64Zn3O2cld-CU9_bvK25GndNViBq4kzBeJaMsAciZ9Inxa6NVzEJ5DE1nywDNYCWq0QuR0hzWC8TMUAAVNal44lqh5CKhrca8xG91v8YFkzj6K9Yhhxgr7HtYccWnfQ5GCB5lnuP8095iKCXMO_9PDOX4PJNg8jCZJMAe-hCLuEsYe35UY957jH
# ...

# %%
# !ls /content/drive/MyDrive/datasets
# Out:
# annotations.zip		 images.zip		   train2014.zip
# flickr30k-images.tar.gz  mdetr_annotations.tar.gz

# %%
# Make sure you have > 105GB disk space on google colab and >150GB space on Google Drive.
# !unzip -q /content/drive/MyDrive/datasets/images.zip
# !unzip -q /content/drive/MyDrive/datasets/train2014.zip
# !tar -xzf /content/drive/MyDrive/datasets/flickr30k-images.tar.gz
# !tar -xzf /content/drive/MyDrive/datasets/mdetr_annotations.tar.gz
# !unzip -q /content/drive/MyDrive/datasets/annotations.zip

# %%
# Make sure you have > 105GB disk space on google colab and >150GB space on Google Drive.
# !tar -xzf /content/drive/MyDrive/datasets/flickr30k-images.tar.gz
# !mv ./flickr30k-images /content/drive/MyDrive/extracted_datasets/

# !tar -xzf /content/drive/MyDrive/datasets/mdetr_annotations.tar.gz
# !mv ./OpenSource /content/drive/MyDrive/extracted_datasets/

# !unzip -q /content/drive/MyDrive/datasets/images.zip
# !mv ./images /content/drive/MyDrive/extracted_datasets/

# !unzip -q /content/drive/MyDrive/datasets/annotations.zip
# !mv ./Annotations /content/drive/MyDrive/extracted_datasets/
# !mv ./Sentences /content/drive/MyDrive/extracted_datasets/

# !unzip -q /content/drive/MyDrive/datasets/train2014.zip
# !mv ./train2014 /content/drive/MyDrive/extracted_datasets/
# Out:
# error:  zipfile read error

# %%
# !unzip -q /content/drive/MyDrive/datasets/train2014.zip
# !mv ./train2014 /content/drive/MyDrive/extracted_datasets/

# %%
# !mv ./Annotations /content/drive/MyDrive/extracted_datasets/
# !mv ./Sentences /content/drive/MyDrive/extracted_datasets/

# %%
# !mv ./train2014 /content/drive/MyDrive/extracted_datasets/
# Out:
# mv: inter-device move failed: './train2014' to '/content/drive/MyDrive/extracted_datasets/train2014'; unable to remove target: Directory not empty

# %%
# !du -h --max-depth=1 /content/train2014
# Out:
# 13G	/content/train2014

# %%
# !unzip -q /content/drive/MyDrive/datasets/images.zip
# !mv ./images /content/drive/MyDrive/extracted_datasets/

# !unzip -q /content/drive/MyDrive/datasets/annotations.zip
# !mv ./Annotations /content/drive/MyDrive/extracted_datasets/
# !mv ./Sentences /content/drive/MyDrive/extracted_datasets/

# !unzip -q /content/drive/MyDrive/datasets/train2014.zip
# !mv ./train2014 /content/drive/MyDrive/extracted_datasets/
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-b93fa3fef136> in <module>
#       1 get_ipython().system('unzip -q /content/drive/MyDrive/datasets/images.zip')
# ----> 2 get_ipython().system('mv ./images /content/drive/MyDrive/extracted_datasets/')
#       3
#       4 get_ipython().system('unzip -q /content/drive/MyDrive/datasets/annotations.zip')
#       5 get_ipython().system('mv ./Annotations /content/drive/MyDrive/extracted_datasets/')
#
# /usr/local/lib/python3.8/dist-packages/google/colab/_shell.py in system(self, *args, **kwargs)
#      93       kwargs.update({'also_return_output': True})
#      94
# ---> 95     output = _system_commands._system_compat(self, *args, **kwargs)  # pylint:disable=protected-access
#      96
#      97     if pip_warn:
#
# ...

# %%
# !ls /content/drive/MyDrive/extracted_datasets

# %%
# !ls
# Out:
# OpenSource  annotations  flickr30k-images  images  mdetr_main.ipynb  train2014

# %%
# !git clone https://github.com/ashkamath/mdetr.git
# !mv  -v ./mdetr/* .
# Out:
# fatal: destination path 'mdetr' already exists and is not an empty directory.
# mv: cannot stat './mdetr/*': No such file or directory

# %%
pretrain_config = """
    {
      "combine_datasets": ["flickr"],
      "combine_datasets_val": ["flickr"],
      "coco_path": "/home/vvvinit/Desktop/mdetr/train2014/",
      "vg_img_path": "/home/vvvinit/Desktop/mdetr/images/",
      "flickr_img_path": "/home/vvvinit/Desktop/mdetr/flickr30k-images/flickr30k-images/",
      "refexp_ann_path": "/home/vvvinit/Desktop/mdetr/OpenSource/",
      "flickr_ann_path": "/home/vvvinit/Desktop/mdetr/OpenSource/",
      "gqa_ann_path": "/home/vvvinit/Desktop/mdetr/OpenSource/",
      "num_queries": 100,
      "refexp_dataset_name": "all",
      "GT_type": "separate",
      "flickr_dataset_path": "/home/vvvinit/Desktop/mdetr/annotations/Annotations/"
  }
"""

with open("./configs/pretrain.json","w+") as f:
  f.writelines(pretrain_config)

# %%
# !python --version
# Out:
# Python 3.8.10

# %%
# !pip install -r requirements.txt
# !pip install submitit
# Out:
# ...
#   Cloning https://github.com/cocodataset/cocoapi.git to /tmp/pip-install-axd9gls8/pycocotools_a378d26712394f04b3ff7016d8db4c31
#   Running command git clone --filter=blob:none --quiet https://github.com/cocodataset/cocoapi.git /tmp/pip-install-axd9gls8/pycocotools_a378d26712394f04b3ff7016d8db4c31
#   Resolved https://github.com/cocodataset/cocoapi.git to commit 8c9bcc3cf640524c4c20a9c40e89cb6a2f2fa0e9
#   Preparing metadata (setup.py) ... done
# ...
#   Cloning https://github.com/cocodataset/panopticapi.git to /tmp/pip-install-axd9gls8/panopticapi_79ef45006cb34deba674b6d6a283134b
#   Running command git clone --filter=blob:none --quiet https://github.com/cocodataset/panopticapi.git /tmp/pip-install-axd9gls8/panopticapi_79ef45006cb34deba674b6d6a283134b
#   Resolved https://github.com/cocodataset/panopticapi.git to commit 7bb4655548f98f3fedc07bf37e9040a992b054b0
#   Preparing metadata (setup.py) ... done
# ...

# %%
# !pip install torch==1.7.1+cu110 torchvision==0.8.2+cu110 torchaudio==0.7.2 -f https://download.pytorch.org/whl/torch_stable.html
# Out:
# Looking in links: https://download.pytorch.org/whl/torch_stable.html
# ...

# %%
# !pip install packaging==21.3

# %%
# Running locally on Nvidia 3070 Ti
import os
os.environ["CUBLAS_WORKSPACE_CONFIG"] = ":4096:8"

# %%
# !python -m torch.distributed.launch --nproc_per_node=1 --use_env main.py --dataset_config configs/pretrain.json --ema
# Out:
# | distributed init (rank 0): env://
# Traceback (most recent call last):
#   File "main.py", line 643, in <module>
#     main(args)
#   File "main.py", line 281, in main
#     dist.init_distributed_mode(args)
#   File "/mnt/c/Users/Vinit/Desktop/mdetr/util/dist.py", line 224, in init_distributed_mode
#     dist.init_process_group(
#   File "/home/vvvinit/anaconda3/envs/vg-mdetr/lib/python3.8/site-packages/torch/distributed/distributed_c10d.py", line 455, in init_process_group
#     barrier()
#   File "/home/vvvinit/anaconda3/envs/vg-mdetr/lib/python3.8/site-packages/torch/distributed/distributed_c10d.py", line 1960, in barrier
#     work = _default_pg.barrier()
# RuntimeError: NCCL error in: /pytorch/torch/lib/c10d/ProcessGroupNCCL.cpp:784, unhandled system error, NCCL version 2.7.8
# Traceback (most recent call last):
#   File "/home/vvvinit/anaconda3/envs/vg-mdetr/lib/python3.8/runpy.py", line 194, in _run_module_as_main
#     return _run_code(code, main_globals, None,
# ...

# %%
# !/home/vvvinit/anaconda3/envs/vg-mdetr/bin/python -u main.py --dataset_config configs/pretrain.json --ema --batch_size 1
# Out:
# Not using distributed mode
# fatal: not a git repository (or any parent up to mount point /mnt)
# Stopping at filesystem boundary (GIT_DISCOVERY_ACROSS_FILESYSTEM not set).
# git:
#   sha: N/A, status: clean, branch: N/A
#
# ...
